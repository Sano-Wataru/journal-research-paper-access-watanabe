# %%
import matplotlib.pyplot as plt

# %%
accuracies_list = [[65.07072905, 98.04560261, 70.01078749, 60.79913607, 63.29386437, 72.0855615, 67.52411576, 70.64516129, 75.80299786], 
                    [42.54624592, 94.35396308, 69.90291262, 59.39524838, 72.98170075, 82.67379679, 71.8113612, 75.16129032, 91.75588865], 
                    [70.40261153, 97.93702497, 69.79503776, 46.76025918, 60.1722282, 60.85561497, 56.48445874, 59.78494624, 60.59957173], 
                    [72.5788901, 99.0228013, 70.01078749, 50.10799136, 65.76964478, 76.25668449, 75.02679528, 72.25806452, 74.51820128], 
                    [71.49075082, 98.58849077, 69.90291262, 71.7062635, 69.1065662, 75.18716578, 75.45551983, 73.87096774, 89.72162741], 
                    [86.39825898, 96.95982628, 70.01078749, 67.49460043, 60.49515608, 58.39572193, 52.84030011, 67.74193548, 65.95289079], 
                    [82.15451578, 90.98805646, 69.68716289, 43.52051836, 58.01937567, 54.65240642, 55.09110397, 61.50537634, 61.3490364], 
                    [84.65723613, 96.19978284, 69.68716289, 60.25917927, 53.17545748, 58.39572193, 54.55519829, 62.79569892, 64.02569593], 
                    [60.17410229, 88.4907709, 69.68716289, 41.46868251, 45.64047363, 53.79679144, 40.08574491, 68.06451613, 62.5267666], 
                    [78.781284, 91.63952226, 69.68716289, 62.52699784, 59.31108719, 55.72192513, 53.80493033, 65.69892473, 64.56102784], 
                    [69.64091404, 81.86753529, 69.68716289, 63.28293737, 56.18945102, 61.92513369, 54.0192926, 61.39784946, 59.85010707], 
                    [75.19042437, 89.4679696, 69.79503776, 55.18358531, 56.5123789, 49.62566845, 40.40728832, 69.13978495, 62.31263383]]

# %%
data_name = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
# accuracies = [65.07072905, 98.04560261, 70.01078749, 60.79913607, 63.29386437, 72.0855615, 67.52411576, 70.64516129, 75.80299786]
# accuracies = [42.54624592, 94.35396308, 69.90291262, 59.39524838, 72.98170075, 82.67379679, 71.8113612, 75.16129032, 91.75588865]
# accuracies = [70.40261153, 97.93702497, 69.79503776, 46.76025918, 60.1722282, 60.85561497, 56.48445874, 59.78494624, 60.59957173]
# accuracies = [72.5788901, 99.0228013, 70.01078749, 50.10799136, 65.76964478, 76.25668449, 75.02679528, 72.25806452, 74.51820128]
# accuracies = [71.49075082, 98.58849077, 69.90291262, 71.7062635, 69.1065662, 75.18716578, 75.45551983, 73.87096774, 89.72162741]
# accuracies = [86.39825898, 96.95982628, 70.01078749, 67.49460043, 60.49515608, 58.39572193, 52.84030011, 67.74193548, 65.95289079]
# accuracies = [82.15451578, 90.98805646, 69.68716289, 43.52051836, 58.01937567, 54.65240642, 55.09110397, 61.50537634, 61.3490364]
# accuracies = [84.65723613, 96.19978284, 69.68716289, 60.25917927, 53.17545748, 58.39572193, 54.55519829, 62.79569892, 64.02569593]
# accuracies = [60.17410229, 88.4907709, 69.68716289, 41.46868251, 45.64047363, 53.79679144, 40.08574491, 68.06451613, 62.5267666]
# accuracies = [78.781284, 91.63952226, 69.68716289, 62.52699784, 59.31108719, 55.72192513, 53.80493033, 65.69892473, 64.56102784]
# accuracies = [69.64091404, 81.86753529, 69.68716289, 63.28293737, 56.18945102, 61.92513369, 54.0192926, 61.39784946, 59.85010707]
# accuracies = [75.19042437, 89.4679696, 69.79503776, 55.18358531, 56.5123789, 49.62566845, 40.40728832, 69.13978495, 62.31263383]

# bar_labels = {'red', 'blue', '_red', 'orange'}
bar_colors = ['red', 'blue', 'green', 'yellow', 'cyan', 'magenta', 'orange', 'teal', 'purple']

# feature = "n"
# feature = "f"
# clustering = "k"
features = ['n', 'd', 'p', 'f']
clusterings = ['n', 'd', 'k']

# %%
for i, accuracies in enumerate(accuracies_list):
    plt.rcParams['font.size'] = 18
    plt.rcParams['ytick.direction'] = 'in'
    plt.rcParams['xtick.direction'] = 'in'
    fig, ax = plt.subplots()
    feature = features[i % len(features)]
    clustering = clusterings[i // len(features)]

    ax.bar(data_name, accuracies, color=bar_colors)
    
    ax.set_ylabel('Accuracy')
    ax.set_title('Accuracies by using test data')
    ax.yaxis.set_label_coords(-0.07, 0.5)
    # ax.legend()
    plt.show()
    fig.savefig('./bar/acc_bar_{}{}.png'.format(feature, clustering))

# %%
# fig, ax = plt.subplots()

# ax.bar(data_name, accuracies, color=bar_colors)

# ax.set_ylabel('Accuracy')
# ax.set_title('Accuracies by using test data')
# # ax.legend()
# plt.show()
# fig.savefig('./bar/acc_bar_{}{}.png'.format(feature, clustering))
