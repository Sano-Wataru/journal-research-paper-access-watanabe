# %%
import matplotlib.pyplot as plt
import pandas

# %%
# feature = "n"
# feature = "n"
# clustering = "k"
df = pandas.read_csv("./csv/journal_val.csv".format(feature, clustering))

# %%
#journal_val.csvの説明
#このファイルと同じディレクトリ内にあるcsvディレクトリの下にあるjournal_val.csvからデータを得る。
#分類モデルごとにエポックごとの検証での分類精度を並べる。（例えばnormals without clusteringならば、クラスタリング手法なしの法線を使用際の分類モデルでの検証結果）
#一番左にはエポック番号を並べる。

# %%
df
# Out:
#      Epoch  normals without clustering  DF without clustering  \
# 0        0                   89.142857              94.104762
# 1        1                   91.628571              94.638095
# 2        2                   98.533333              99.038095
# 3        3                   95.838095              97.904762
# 4        4                   98.600000              98.142857
# ..     ...                         ...                    ...
# 107    107                         NaN                    NaN
# 108    108                         NaN                    NaN
# 109    109                         NaN                    NaN
# 110    110                         NaN                    NaN
# 111    111                         NaN                    NaN
#
#      POV without clustering  FPFH without clustering  normals with DBSCAN  \
# 0                 96.295238                91.733333            95.390476
# 1                 97.019048                95.600000            95.019048
# 2                 93.380952                96.800000            82.733333
# 3                 98.314286                95.219048            97.761905
# 4                 98.704762                96.723810            98.523810
# ..                      ...                      ...                  ...
# 107                     NaN                      NaN                  NaN
# 108                     NaN                      NaN                  NaN
# 109                     NaN                      NaN                  NaN
# 110                     NaN                      NaN                  NaN
# 111                     NaN                      NaN                  NaN
#
#      DF with DBSCAN  POV with DBSCAN  FPFH with DBSCAN  normals with k-means  \
# 0         92.647619        98.371429         91.771429             83.104762
# 1         98.295238        98.152381         96.238095             94.733333
# 2         96.104762        95.904762         97.009524             95.190476
# 3         93.752381        99.304762         95.266667             95.361905
# 4         97.504762        96.247619         95.638095             95.980952
# ..              ...              ...               ...                   ...
# 107             NaN              NaN         98.104762                   NaN
# 108             NaN              NaN         98.847619                   NaN
# 109             NaN              NaN         99.561905                   NaN
# 110             NaN              NaN         99.409524                   NaN
# 111             NaN              NaN         99.714286                   NaN
#
#      DF with k-means  POV with k-means  FPFH with k-means
# 0          91.019048         93.276190          83.361905
# 1          83.333333         88.600000          85.771429
# 2          95.095238         94.571429          91.104762
# 3          94.723810         94.904762          92.857143
# 4          92.942857         89.742857          94.714286
# ..               ...               ...                ...
# 107              NaN               NaN                NaN
# 108              NaN               NaN                NaN
# 109              NaN               NaN                NaN
# 110              NaN               NaN                NaN
# 111              NaN               NaN                NaN
#
# [112 rows x 13 columns]

# %%
def graph(x, y, xlabel, ylabels, colors, fname, cls):
    # print(ylabels)
    plt.rcParams['font.size'] = 24
    plt.rcParams['ytick.direction'] = 'in'
    plt.rcParams['xtick.direction'] = 'in'
    
    fig = plt.figure(figsize=(10,6))
    plt.xlabel(xlabel)
    plt.ylabel(fname)
    plt.title('Validation accuracies')
    
    for i in range(len(ylabels)):
        # print(ylabels[i+1].replace(' ', '_'))
        # plt.plot(x, y[ylabels[i+1]], marker='.', color=colors[i], label=ylabels[i+1].replace(' ', '_'))
        plt.plot(x, y[ylabels[i]], marker='.', color=colors[i], label=ylabels[i].replace(' ', '_'))
    plt.xlim(left=0.0)
    plt.ylim(0.0, 100.0)
    plt.legend()
    plt.show()
    fig.savefig('./{}/{}.png'.format(cls, fname.replace(' ', '_')))

# %%
[col for col in df.columns if "normal" in col]
# Out:
# ['normals without clustering', 'normals with DBSCAN', 'normals with k-means']

# %%
#Accuracies_of_validation_〇〇.png（〇〇にはnormal、DF、POV、FPFHがそれぞれ入る）
#各特徴を使った分類モデルの検証での分類結果
#accディレクトリの下に置く
xlabel = 'Epoch'
features = ["normals", "DF", "POV", "FPFH"]
colors = ['red', 'green', 'blue']
for feature in features:
    columns = [col for col in df.columns if feature in col]
    graph(df[xlabel], df[columns], xlabel, columns, colors, 'Accuracies of validation {}'.format(feature), 'acc')

# %%
# xlabel = 'Epoch'
# ylabel1 = 'Train'
# ylabel2 = 'Validation'
# colors = ['red', 'orange', 'yellow', 'lime', 'green', 'teal', 'cyan', 'azure', 'blue', 'purple', 'magenta', 'crimson']
# graph(df[xlabel], df.drop(xlabel, axis=1), xlabel, df.columns, colors, 'Accuracies of validation', 'acc')

# %%
# graph(df[xlabel], [df['Train_Loss'], df['Test_Loss']], xlabel, ['Loss', ylabel1, ylabel2], ['green', 'orange'], 'loss_{}{}'.format(feature, clustering), 'loss')
